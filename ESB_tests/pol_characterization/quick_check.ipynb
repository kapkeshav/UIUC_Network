# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import datetime
import pandas as pd
import qutip as qutip

# %%
data = np.loadtxt("esb_process_tomography_20230105_1.txt")

# %%
pow_v = np.array([d[3]+d[4] for d in data])
pow_d = np.array([d[5]+d[6] for d in data])

# %%
plt.plot(pow_v)

# %%
plt.plot(pow_d)

# %%
plt.plot(pow_v+pow_d)
