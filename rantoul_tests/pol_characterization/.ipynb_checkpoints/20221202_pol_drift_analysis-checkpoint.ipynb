# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import datetime
import pandas as pd
import qutip as qutip

# %%
data = pd.read_csv("rantoul_full_pol_4th_floor_20221201.csv",delimiter=";",skiprows=14)

# %%
v_data = np.array([float(d.replace(',','.')) for d in data['Power (W).2']])
h_data = np.array([float(d.replace(',','.')) for d in data['Power (W).1']])
#float(data['Power (W).2'][0])

# %%
ratio_hv = v_data/h_data

# %%
a_data = np.array([float(d.replace(',','.')) for d in data['Power (W).3']])
d_data = np.array([float(d.replace(',','.')) for d in data['Power (W)']])

# %%
ratio_da = a_data/d_data

# %%
times = [datetime.datetime.strptime(data['Date (MM/dd/yyyy) '][i][1:]+d,'%m/%d/%Y %H:%M:%S.%f') for i,d in enumerate(data['Time of day (hh:mm:ss) '])]

# %%
fig, ax = plt.subplots()
#ax2 = ax.twinx()
ax.plot(times,np.degrees(np.arctan(ratio_hv)))
#ax2.plot(temp_times,temp_20222211,color="orange")
#plt.gcf().autofmt_xdate()
myFmt = mdates.DateFormatter('%H:%M')
ax.xaxis.set_major_formatter(myFmt)
ax.set_ylabel(r"$\theta (^0)$")
#ax2.set_ylabel("Temperature (F)")
plt.xlabel("Time")
plt.title("4th floor Rantoul loop")
plt.savefig('theta_time_20221201.pdf')

# %%
fig, ax = plt.subplots()
#ax2 = ax.twinx()
ax.plot(times,np.degrees(np.arctan(ratio_da)))
#ax2.plot(temp_times,temp_20222211,color="orange")
#plt.gcf().autofmt_xdate()
myFmt = mdates.DateFormatter('%H:%M')
ax.xaxis.set_major_formatter(myFmt)
ax.set_ylabel(r"$\phi (^0)$")
#ax2.set_ylabel("Temperature (F)")
plt.xlabel("Time")
plt.title("4th floor Rantoul loop")
plt.savefig('phi_time_20221201.pdf')

# %%
theta = np.arctan(v_data/h_data)
phi = np.arctan((0.5-a_data)/(0.5-d_data))
x = np.sin(theta)*np.cos(phi)
y = np.sin(theta)*np.sin(phi)
z = np.cos(theta)

# %%
b = qutip.Bloch()

# %%
for i,j in enumerate([1,2,3]):
    print(i)
# Out:
# 0
# 1
# 2

# %%
len(x)/100
# Out:
# 540.12

# %%
b.add_points([x[0],y[0],z[0]],meth='m')
b.add_points([x[-1],y[-1],z[-1]],meth='m')

# %%
for i in range(100):
    b.add_points([x[540*i],y[540*i],z[540*i]],meth='m')

# %%
b.render()

# %%
fig, ax = plt.subplots()
#ax2 = ax.twinx()
thetas = np.degrees(np.arctan(ratio_hv))
ax.plot(times[1:],[thetas[i+1]-thetas[i] for i in range(len(thetas)-1)])
#ax2.plot(temp_times,temp_20222211,color="orange")
#plt.gcf().autofmt_xdate()
myFmt = mdates.DateFormatter('%H:%M')
ax.xaxis.set_major_formatter(myFmt)
ax.set_ylabel(r"$\Delta \theta (^0)$")
#ax2.set_ylabel("Temperature (F)")
plt.xlabel("Time")
plt.title("4th floor Rantoul loop")
#plt.savefig('theta_time_20221201.pdf')
# Out:
# Text(0.5, 1.0, '4th floor Rantoul loop')

# %%
fig, ax = plt.subplots()
#ax2 = ax.twinx()
phis = np.degrees(np.arctan(ratio_da))
ax.plot(times[1:],[phis[i+1]-phis[i] for i in range(len(phis)-1)])
#ax2.plot(temp_times,temp_20222211,color="orange")
#plt.gcf().autofmt_xdate()
myFmt = mdates.DateFormatter('%H:%M')
ax.xaxis.set_major_formatter(myFmt)
ax.set_ylabel(r"$\Delta \phi (^0)$")
#ax2.set_ylabel("Temperature (F)")
plt.xlabel("Time")
plt.title("4th floor Rantoul loop")
#plt.savefig('theta_time_20221201.pdf')
# Out:
# Text(0.5, 1.0, '4th floor Rantoul loop')
